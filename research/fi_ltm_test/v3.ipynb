# %%
from pathlib import Path
from datetime import datetime
import quant
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

import warnings
warnings.filterwarnings(action='ignore')

# %%
CONFIG_PATH = Path(str(__vsc_ipynb_file__)).parent.parent.parent / "lseg-data.config.json"
VIX_PATH = Path(str(__vsc_ipynb_file__)).parent.parent.parent / "data" / "vix.csv"
session = quant.SessionProvider(CONFIG_PATH)

# %%
vix = pd.read_csv(VIX_PATH, sep='\t', parse_dates=True, index_col=0).rename(columns={"Close": "VIX_Close"})

# %%
import lseg.data as ld

with session as client:
    all_us_industrials_equities = ld.discovery.Screener('U(IN(Equity(active,public,primary))/*UNV:Public*/), IN(TR.HQCountryCode,"US"), IN(TR.GICSSectorCode,"20")')
    all_us_industrials_equities_rics = list(all_us_industrials_equities)
    
    equities = client.equities.upgrade_l1_equity(all_us_industrials_equities_rics)

    for equity in equities:
        bonds = client.equities.bonds_of_equity(equity)
        
        print(f'{equity.display_name} ({equity.ticker}) had {len(bonds)} bonds')
# Out:
# CPI Aerostructures Inc (CVU) had 0 bonds
# Emerson Electric Co (EMR) had 83 bonds
# Ennis Inc (EBF) had 0 bonds
# Environmental Tectonics Corp (ETCC) had 0 bonds
# Equifax Inc (EFX) had 22 bonds
# Espey MFG & Electronics Corp (ESP) had 0 bonds
# Expeditors International of Washington Inc (EXPD) had 0 bonds
# Exponent Inc (EXPO) had 0 bonds
# Fastenal Co (FAST) had 0 bonds
# FedEx Corp (FDX) had 106 bonds
# Federal Signal Corp (FSS) had 0 bonds
# Fluor Corp (FLR) had 8 bonds
# L B Foster Co (FSTR) had 0 bonds
# Franklin Electric Co Inc (FELE) had 0 bonds
# AAR Corp (AIR) had 3 bonds
# CECO Environmental Corp (CECO) had 0 bonds
# GATX Corp (GATX) had 19 bonds
# Gencor Industries Inc (GENC) had 0 bonds
# General Dynamics Corp (GD) had 12 bonds
# AER Energy Resources Inc (AERN) had 0 bonds
# General Electric Co (GE) had 200 bonds
# GEE Group Inc (JOB) had 0 bonds
# Air T Inc (AIRT) had 2 bonds
# Alaska Air Group Inc (ALK) had 4 bonds
# Albany International Corp (AIN) had 0 bonds
# Gresham Worldwide Inc (GIGAQ) had 0 bonds
# Gresham Worldwide Inc (GIGAQ) had 0 bonds
# Matson Inc (MATX) had 1 bonds
# ATI Inc (ATI) had 4 bonds
# Honeywell International Inc (HON) had 102 bonds
# Howmet Aerospace Inc (HWM) had 11 bonds
# ABM Industries Inc (ABM) had 0 bonds
# Gorman- Rupp Co (GRC) had 0 bonds
# Graco Inc (GGG) had 0 bonds
# Graham Corp (GHM) had 0 bonds
# WW Grainger Inc (GWW) had 4 bonds
# Granite Construction Inc (GVA) had 4 bonds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 10
#       6
#       7     equities = client.equities.upgrade_l1_equity(all_us_industrials_equities_rics)
#       8
#       9     for equity in equities:
# ---> 10         bonds = client.equities.bonds_of_equity(equity)
#      11
#      12         print(f'{equity.display_name} ({equity.ticker}) had {len(bonds)} bonds')
#
# File ~/Code/quant/quant/equities.py:366, in EquitiesClient.bonds_of_equity(self, l1)
#     363 if isinstance(l1, str):
#     364     l1 = self.__gen_init_l1(l1)[0]
# --> 366 df = ld.discovery.search(
#     367     view = ld.discovery.Views.GOV_CORP_INSTRUMENTS,
#     368     filter = f"ParentOAPermID eq '{l1.perm_id}' and IsActive eq true and not(AssetStatus in ('MAT'))",
#     369     select = "DocumentTitle, RIC, PermID, PI, BusinessEntity",
#     370     top = 10000)
#     372 return [BondL1.from_row(row) for _, row in df.iterrows()]
#
# File ~/Code/quant/.venv/lib/python3.13/site-packages/lseg/data/discovery/_search.py:131, in search(query, view, filter, order_by, boost, select, top, skip, group_by, group_count, features, scope, terms, navigators, extended_params)
#      12 def search(
#      13     query: OptStr = None,
#      14     view: Union[Views, str] = Views.SEARCH_ALL,
#    (...)     27     extended_params: "ExtendedParams" = None,
#      28 ) -> "pd.DataFrame":  # NOSONAR
#      29     """
#      30     The search service identifies a matching set of documents which satisfy the caller's criteria, sorts it,
#      31     and selects a subset of the matches to return as the result set. Each step can be controlled via parameters.
#    (...)    111     ... )
#     112     """
#     113     return (
#     114         content.search.Definition(
#     115             query=query,
#     116             view=view,
#     117             filter=filter,
#     118             order_by=order_by,
#     119             boost=boost,
#     120             select=select,
#     121             top=top,
#     122             skip=skip,
#     123             group_by=group_by,
#     124             group_count=group_count,
#     125             navigators=navigators,
#     126             features=features,
#     127             scope=scope,
#     128             terms=terms,
#     129             extended_params=extended_params,
#     130         )
# --> 131         .get_data()
#     132         .data.df
#     133     )
#
# File ~/Code/quant/.venv/lib/python3.13/site-packages/lseg/data/delivery/_data/_data_provider_layer.py:139, in DataProviderLayer.get_data(self, session)
#     125 """
#     126 Sends a request to the client file store to retrieve the previously defined data.
#     127
#    (...)    136
#     137 """
#     138 session = get_valid_session(session)
# --> 139 response = get_data(self._data_type, self._provider, session, **self._kwargs)
#     140 _check_response(response, session.config)
#     141 return response
#
# File ~/Code/quant/.venv/lib/python3.13/site-packages/lseg/data/delivery/_data/_data_provider_layer.py:50, in get_data(data_type, provider, session, **kwargs)
#      43 # Library usage logging
#      44 get_usage_logger().log_func(
#      45     name=f"{ModuleName.DELIVERY}.{DataProviderLayer._USAGE_CLS_NAME}.get_data",
#      46     func_path=f"{DataProviderLayer.__module__}.{DataProviderLayer.__qualname__}.get_data",
#      47     kwargs={"url": url, "auto_retry": auto_retry, **kwargs},
#      48     desc={FilterType.SYNC, FilterType.LAYER_DELIVERY},
#      49 )
# ---> 50 response = provider.get_data(session, url, auto_retry=auto_retry, **kwargs)
#      51 return response
#
# File ~/Code/quant/.venv/lib/python3.13/site-packages/lseg/data/delivery/_data/_data_provider.py:80, in DataProvider.get_data(self, session, *args, **kwargs)
#      78 raise_if_closed(session)
#      79 request = self.request.create(session, *args, **kwargs)
# ---> 80 raw_response = self.connection.send(request, session, *args, **kwargs)
#      81 return self._process_response(raw_response, request, session, *args, **kwargs)
#
# File ~/Code/quant/.venv/lib/python3.13/site-packages/lseg/data/delivery/_data/_connection.py:13, in HttpSessionConnection.send(self, request, session, auto_retry, *_, **__)
#      11 def send(self, request: "Request", session: "Session", *_, auto_retry=False, **__) -> "httpx.Response":
#      12     request.auto_retry = auto_retry
# ---> 13     return session.http_request(request)
#
# File ~/Code/quant/.venv/lib/python3.13/site-packages/lseg/data/_core/session/_platform_session.py:200, in PlatformSession.http_request(self, request)
#     199 def http_request(self, request: "Request") -> "httpx.Response":
# --> 200     return self._connection.http_request(request)
#
# File ~/Code/quant/.venv/lib/python3.13/site-packages/lseg/data/_core/session/connection.py:268, in PlatformDataConnection.http_request(self, request)
#     267 def http_request(self, request: "Request") -> httpx.Response:
# --> 268     return self.session._http_service.request(request)
#
# File ~/Code/quant/.venv/lib/python3.13/site-packages/lseg/data/_core/session/http_service.py:344, in HTTPService.request(self, request)
#     341     self._client.open()
#     343 try:
# --> 344     response = self._client.send(request)
#     345 except RequestRetryException as error:
#     346     self.error(error)
#
# File ~/Code/quant/.venv/lib/python3.13/site-packages/lseg/data/_core/session/http_service.py:233, in HTTPClient.send(self, request)
#     230     response = client.send(request, timeout=request.timeout, follow_redirects=True)
#     232 else:
# --> 233     response = client.send(request, follow_redirects=True)
#     235 return response
#
# File ~/Code/quant/.venv/lib/python3.13/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File ~/Code/quant/.venv/lib/python3.13/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File ~/Code/quant/.venv/lib/python3.13/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File ~/Code/quant/.venv/lib/python3.13/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File ~/Code/quant/.venv/lib/python3.13/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)    233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File ~/Code/quant/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Code/quant/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Code/quant/.venv/lib/python3.13/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Code/quant/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Code/quant/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Code/quant/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Code/quant/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Code/quant/.venv/lib/python3.13/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~/miniconda3/lib/python3.13/ssl.py:1285, in SSLSocket.recv(self, buflen, flags)
#    1281     if flags != 0:
#    1282         raise ValueError(
#    1283             "non-zero flags not allowed in calls to recv() on %s" %
#    1284             self.__class__)
# -> 1285     return self.read(buflen)
#    1286 else:
#    1287     return super().recv(buflen, flags)
#
# File ~/miniconda3/lib/python3.13/ssl.py:1140, in SSLSocket.read(self, len, buffer)
#    1138         return self._sslobj.read(len, buffer)
#    1139     else:
# -> 1140         return self._sslobj.read(len)
#    1141 except SSLError as x:
#    1142     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
